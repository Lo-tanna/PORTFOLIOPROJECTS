# %%
#seaborn is also visulization library and it uses the matplotlib background
#importing the libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
date = pd.read_excel("products summary.xlsx",sheet_name="sales details")
date
# Out:
#     SA. RAP ID   ZONE SALES RAP       DATE    MONTH   PRODUCT  BOXES   \
# 0        SR001  SOUTH     PETER 2021-01-01  January    Orange      18
# 1        SR002  SOUTH    BISOLA 2021-01-01  January  Cherries      17
# 2        SR003  SOUTH  VICTORIA 2021-01-01  January    Banana      92
# 3        SR004   EAST    DANIEL 2021-01-01  January     Apple      88
# 4        SR005   EAST    LOVETH 2021-01-01  January    Grapes      24
# ..         ...    ...       ...        ...      ...       ...     ...
# 442      SR008   WEST    GLORIA 2021-03-31    March  Cherries      12
# 443      SR009   WEST    ENIOLA 2021-03-31    March    Banana      91
# 444      SR010  NORTH    HANNEY 2021-03-31    March     Apple      56
# 445      SR011  NORTH  TEMITOPE 2021-03-31    March    Grapes      30
# 446      SR012  NORTH      WURA 2021-03-31    March   Mangoes      83
#
#      UNIT PRICE  TOTAL
# 0            25    450
# 1            78   1326
# 2            18   1656
# 3            45   3960
# ...

# %%
plt.figure(figsize=(11,5))
sns.barplot(x="SALES RAP",y="UNIT PRICE",data=date)
plt.show()

# %%
#set a tittle
plt.figure(figsize=(11,5))
sns.barplot(x="SALES RAP",y="UNIT PRICE",data=date).set_title("UNIT PRICE BY SALES RAP")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.stripplot(x="PRODUCT",y="TOTAL",data=date).set_title("TOTAL PRODUCT SALES")
plt.xlabel("PRODUCT")
plt.ylabel("TOTAL")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.lineplot(x="MONTH",y="TOTAL",data=date).set_title("TOTAL SALES BY MONTH")
plt.show()

# %%
plt.figure(figsize=(11,5))
sns.barplot(x="TOTAL",y="ZONE",data=date).set_title("TOTAL SALES BY ZONE")
plt.show()

# %%
"""with subplot () function you can draw multiple plots in one figure
The subplot() function takes three arguments that describes the layout of the figure.
The layout is organized in rows and columns, which are represented by the first
and second argument.
The third argument represents the index of the current plot. plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
pit.subplot(1, 2, 2)
the figure has 1 row, 2 columns, and this plot is the second plot.""""
# Out:
#   File "<ipython-input-22-a00a0b8caabc>", line 8
#     the figure has 1 row, 2 columns, and this plot is the second plot.""""
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.barplot(x="SALES RAP",y="UNIT PRICE",data=date).set_title("UNIT PRICE BY SALES RAP")
plt.subplot(2,2,2)
sns.stripplot(x="PRODUCT",y="TOTAL",data=date).set_title("TOTAL PRODUCT SALES")
plt.subplot(2,2,3)
sns.lineplot(x="MONTH",y="TOTAL",data=date).set_title("TOTAL SALES BY MONTH")
plt.subplot(2,2,4)
sns.barplot(x="TOTAL",y="ZONE",data=date).set_title("TOTAL SALES BY ZONE")
plt.show()
